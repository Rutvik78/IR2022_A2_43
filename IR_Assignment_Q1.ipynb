# %%
import pandas as pd
import numpy as np
import nltk
nltk.download('stopwords')
from glob import glob
import random
import re
import pickle
from nltk import word_tokenize
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer,WordNetLemmatizer
nltk.download('wordnet')
from nltk.tokenize import word_tokenize
nltk.download('punkt')
from nltk.corpus.reader.pl196x import TYPE
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## ***JACCARD COEFFICIENT***

# %%
textdf = pickle.load(open("/content/drive/MyDrive/IR/textdf2.pkl",'rb'))

# %%
textdf.head()
# Out:
#    id                                               Text
# 1  d1  [rinaldo, laws, leaving, washington, area, ear...
# 2  d2  [day, age, overcrowding, ballpark, traitors, l...
# 3  d3  [department, agriculture, bulletin, notes, ope...
# 4  d4  [hate, boston, celtics, hate, women, boxing, r...
# 5  d5  [mother, dictionary, amnesia, condition, enabl...

# %%
# calculate |A or B|
def union(l1,l2):
  #comp = 0
  result = []
  n,m = len(l1),len(l2)
  i=j=0
  while i<n and j<m:
    if l1[i]<l2[j]:
      result.append(l1[i])
      i+=1
      #comp+=1
    elif l1[i]>l2[j]:
      result.append(l2[j])
      j+=1
     # comp+=1
    else:
      result.append(l1[i])
      i+=1
      j+=1
      #comp+=1

  while(i<n):
    result.append(l1[i])
    i+=1

  while(j<len(l2)):
    result.append(l2[j])
    j+=1

  return len(result)


## calculate |A & B|
def intersection(l1,l2):
  result = []
  n,m = len(l1),len(l2)
  i=j=0
  while i<n and j<m:
    if l1[i]<l2[j]:
      i+=1
      #comp+=1
    elif l1[i]>l2[j]:
      j+=1
      #comp+=1
    else:
      result.append(l1[i])
      i+=1
      j+=1
      #comp+=1
  return len(result)

# %%
def preprocessing(query):
  tokenizer = nltk.RegexpTokenizer(r"\w+")   # Tokenizer
  tokens = tokenizer.tokenize(query) 

  # convert in lower case
  for i in range(len(tokens)):
    tokens[i] = tokens[i].lower()

  # remove stop words
  sw = set(stopwords.words('english'))
  tokens = [w for w in tokens if not w in sw]
  return tokens

# %%
# Calculation of Jaccard coefficient

def jaccardCoefficient(query):
  tokens = preprocessing(query)
  print(tokens)
  jc = {}
  for i in textdf.index:
    intlen = intersection(tokens,textdf.loc[i,'Text'])
    unilen = union(tokens,textdf.loc[i,'Text'])
    jc["d"+ str(i)] = intlen/unilen
  
  jc = pd.DataFrame.from_dict(jc,orient = 'index')
  jc.rename(columns={0:'Jaccard Coefficient'},inplace=True)
  jc.sort_values('Jaccard Coefficient',inplace=True,ascending=False)
  return jc

# %%
print(jaccardCoefficient("department agriculture").head())
# Out:
# ['department', 'agriculture']
#       Jaccard Coefficient
# d3               0.007782
# d456             0.002564
# d1               0.000000
# d754             0.000000
# d760             0.000000

# %% [markdown]
# ## **TF-IDF MATRIX**

# %%
vocab = []
for i in textdf.index:
  vocab += textdf.loc[i,'Text']

vocab1 = list(dict.fromkeys(vocab))
# for i in range(len(vocab1)):
#   if vocab1[i][0] == 't' and vocab1[i][1] == 't':
#     vocab1[i] = vocab1[i][1:]

# %%
# binarytf = pd.DataFrame(0,columns=vocab1,index=textdf.id)
# rowcounttf = pd.DataFrame(0,columns=vocab1,index=textdf.id)

# %%
# def TF():
#   for w in vocab1:
#     for i in textdf.index:
#       if textdf.loc[i,'Text'].count(w)>0:
#         binarytf.loc[textdf.loc[i,'id'],w] = 1;
#         rowcounttf.loc[textdf.loc[i,'id'],w] = textdf.loc[i,'Text'].count(w);

# %%
# TF()
# binarytf.head()
# rowcounttf.head()

# %%
# pickle.dump(binarytf,open("/content/drive/MyDrive/IR/binarytf",'wb'))
# pickle.dump(rowcounttf,open("/content/drive/MyDrive/IR/rowcounttf",'wb'))

# %%
binarytf = pickle.load(open("/content/drive/MyDrive/IR/binarytf",'rb'))
rowcounttf = pickle.load(open("/content/drive/MyDrive/IR/rowcounttf",'rb'))

# %%
binarytf.head()
# Out:
#     rinaldo  laws  leaving  washington  area  early  may  thought  \
# id
# d1        1     1        1           1     1      1    1        1
# d2        0     0        0           0     0      0    1        0
# d3        0     0        0           0     1      0    0        0
# d4        0     0        0           0     0      0    0        0
# d5        0     0        0           0     0      0    0        0
#
#     appropriate  share  ...  tspecimen  tego  tsucceed  apolloway  unetix  \
# id                      ...
# d1            1      1  ...          0     0         0          0       0
# d2            0      0  ...          0     0         0          0       0
# d3            0      0  ...          0     0         0          0       0
# d4            0      0  ...          0     0         0          0       0
# d5            0      0  ...          0     0         0          0       0
#
#     calistogas  commencing  moffett  whereof  hereto
# id
# ...

# %%
rowcounttf.head()
# Out:
#     rinaldo  laws  leaving  washington  area  early  may  thought  \
# id
# d1        1     2        2           1     1      1    3        1
# d2        0     0        0           0     0      0    2        0
# d3        0     0        0           0     1      0    0        0
# d4        0     0        0           0     0      0    0        0
# d5        0     0        0           0     0      0    0        0
#
#     appropriate  share  ...  tspecimen  tego  tsucceed  apolloway  unetix  \
# id                      ...
# d1            1      1  ...          0     0         0          0       0
# d2            0      0  ...          0     0         0          0       0
# d3            0      0  ...          0     0         0          0       0
# d4            0      0  ...          0     0         0          0       0
# d5            0      0  ...          0     0         0          0       0
#
#     calistogas  commencing  moffett  whereof  hereto
# id
# ...

# %%
termfrequency = pd.DataFrame(0,columns=vocab1,index=textdf.id)

# %%
# for c in list(rowcounttf.columns):
#   termfrequency.loc[:,c] = list(rowcounttf.loc[:,c]/rowcounttf.loc[:,c].sum())

# %%
termfrequency.head()
# Out:
#     rinaldo  laws  leaving  washington  area  early  may  thought  \
# id
# d1        0     0        0           0     0      0    0        0
# d2        0     0        0           0     0      0    0        0
# d3        0     0        0           0     0      0    0        0
# d4        0     0        0           0     0      0    0        0
# d5        0     0        0           0     0      0    0        0
#
#     appropriate  share  ...  tspecimen  tego  tsucceed  apolloway  unetix  \
# id                      ...
# d1            0      0  ...          0     0         0          0       0
# d2            0      0  ...          0     0         0          0       0
# d3            0      0  ...          0     0         0          0       0
# d4            0      0  ...          0     0         0          0       0
# d5            0      0  ...          0     0         0          0       0
#
#     calistogas  commencing  moffett  whereof  hereto
# id
# ...

# %%
#pickle.dump(termfrequency,open("/content/drive/MyDrive/IR/termfrequency",'wb'))

# %%
termfrequency = pickle.load(open("/content/drive/MyDrive/IR/termfrequency",'rb'))

# %%
termfrequency.head()
# Out:
#     rinaldo      laws   leaving  washington      area     early       may  \
# id
# d1     0.25  0.012658  0.010417     0.00641  0.002558  0.002865  0.001715
# d2     0.00  0.000000  0.000000     0.00000  0.000000  0.000000  0.001144
# d3     0.00  0.000000  0.000000     0.00000  0.002558  0.000000  0.000000
# d4     0.00  0.000000  0.000000     0.00000  0.000000  0.000000  0.000000
# d5     0.00  0.000000  0.000000     0.00000  0.000000  0.000000  0.000000
#
#      thought  appropriate     share  ...  tspecimen  tego  tsucceed  \
# id                                   ...
# d1  0.001183     0.010101  0.007812  ...        0.0   0.0       0.0
# d2  0.000000     0.000000  0.000000  ...        0.0   0.0       0.0
# d3  0.000000     0.000000  0.000000  ...        0.0   0.0       0.0
# d4  0.000000     0.000000  0.000000  ...        0.0   0.0       0.0
# d5  0.000000     0.000000  0.000000  ...        0.0   0.0       0.0
#
# ...

# %%
lognormalization = pd.DataFrame(0,columns=vocab1,index=textdf.id)

# %%
import math

# %%
# for c in rowcounttf.columns:
#   lognormalization.loc[:,c] = np.log10(1+rowcounttf.loc[:,c])

# %%
# lognormalization.head()

# %%
# pickle.dump(lognormalization,open("/content/drive/MyDrive/IR/lognormalization",'wb'))

# %%
lognormalization = pickle.load(open("/content/drive/MyDrive/IR/lognormalization",'rb'))

# %%
lognormalization.head()
# Out:
#     rinaldo      laws   leaving  washington     area    early       may  \
# id
# d1  0.30103  0.477121  0.477121     0.30103  0.30103  0.30103  0.602060
# d2  0.00000  0.000000  0.000000     0.00000  0.00000  0.00000  0.477121
# d3  0.00000  0.000000  0.000000     0.00000  0.30103  0.00000  0.000000
# d4  0.00000  0.000000  0.000000     0.00000  0.00000  0.00000  0.000000
# d5  0.00000  0.000000  0.000000     0.00000  0.00000  0.00000  0.000000
#
#     thought  appropriate    share  ...  tspecimen  tego  tsucceed  apolloway  \
# id                                 ...
# d1  0.30103      0.30103  0.30103  ...        0.0   0.0       0.0        0.0
# d2  0.00000      0.00000  0.00000  ...        0.0   0.0       0.0        0.0
# d3  0.00000      0.00000  0.00000  ...        0.0   0.0       0.0        0.0
# d4  0.00000      0.00000  0.00000  ...        0.0   0.0       0.0        0.0
# d5  0.00000      0.00000  0.00000  ...        0.0   0.0       0.0        0.0
#
# ...

# %%
dnormalization = pd.DataFrame(0,columns=vocab1,index=textdf.id)

# %%
rowcounttf.loc[:,'laws']/max(rowcounttf.loc[:,'laws'])
# Out:
# id
# d1       0.068966
# d2       0.000000
# d3       0.000000
# d4       0.000000
# d5       0.000000
#            ...
# d1129    0.000000
# d1130    0.000000
# d1131    0.000000
# d1132    0.000000
# d1133    0.000000
# Name: laws, Length: 1133, dtype: float64

# %%
# for c in list(rowcounttf.columns):
#   dnormalization.loc[:,c] = 0.5+0.5*(rowcounttf.loc[:,c]/max(rowcounttf.loc[:,c]))

# %%
# pickle.dump(dnormalization,open("/content/drive/MyDrive/IR/dnormalization",'wb'))

# %%
dnormalization = pickle.load(open("/content/drive/MyDrive/IR/dnormalization",'rb'))

# %%
# docfreq = [len(binarytf[binarytf[f]!=0]) for f in binarytf.columns]

# %%
# N = len(binarytf)

# %%
# idf = [np.log10(N/(df+1)) for df in docfreq]

# %%
# binary_tfidf = binarytf.T
# rowcount_tfidf = rowcounttf.T
# termfrequency_tfidf = termfrequency.T
# lognormalization_tfidf = lognormalization.T
# dnormalization_tfidf = dnormalization.T

# %%
# for c in binary_tfidf.columns:
#   binary_tfidf[c] = binary_tfidf[c]*idf
#   rowcount_tfidf[c]  = rowcount_tfidf[c]*idf
#   termfrequency_tfidf[c] = termfrequency_tfidf[c]*idf
#   lognormalization_tfidf[c] = lognormalization_tfidf[c]*idf
#   dnormalization_tfidf[c] = dnormalization_tfidf[c]*idf

# %%
# binary_tfidf = binary_tfidf.T
# rowcount_tfidf = rowcount_tfidf.T
# termfrequency_tfidf = termfrequency_tfidf.T
# lognormalization_tfidf = lognormalization_tfidf.T
# dnormalization_tfidf = dnormalization_tfidf.T

# %%
# pickle.dump(binary_tfidf,open("/content/drive/MyDrive/IR/binary_tfidf",'wb'))
# pickle.dump(rowcount_tfidf,open("/content/drive/MyDrive/IR/rowcount_tfidf",'wb'))
# pickle.dump(termfrequency_tfidf,open("/content/drive/MyDrive/IR/termfrequency_tfidf",'wb'))
# pickle.dump(lognormalization_tfidf,open("/content/drive/MyDrive/IR/lognormalization_tfidf",'wb'))
# pickle.dump(dnormalization_tfidf,open("/content/drive/MyDrive/IR/dnormalization_tfidf",'wb'))

# %%
binary_tfidf = pickle.load(open("/content/drive/MyDrive/IR/binary_tfidf",'rb'))
rowcount_tfidf = pickle.load(open("/content/drive/MyDrive/IR/rowcount_tfidf",'rb'))
termfrequency_tfidf = pickle.load(open("/content/drive/MyDrive/IR/termfrequency_tfidf",'rb'))
lognormalization_tfidf = pickle.load(open("/content/drive/MyDrive/IR/lognormalization_tfidf",'rb'))
dnormalization_tfidf = pickle.load(open("/content/drive/MyDrive/IR/dnormalization_tfidf",'rb'))

# %%
binary_tfidf.head()
# Out:
#     rinaldo      laws  leaving  washington     area     early       may  \
# id
# d1  2.45217  1.306042  0.94702    1.184998  0.80381  0.791779  0.354392
# d2  0.00000  0.000000  0.00000    0.000000  0.00000  0.000000  0.354392
# d3  0.00000  0.000000  0.00000    0.000000  0.80381  0.000000  0.000000
# d4  0.00000  0.000000  0.00000    0.000000  0.00000  0.000000  0.000000
# d5  0.00000  0.000000  0.00000    0.000000  0.00000  0.000000  0.000000
#
#      thought  appropriate     share  ...  tspecimen  tego  tsucceed  \
# id                                   ...
# d1  0.564271     1.190907  1.085747  ...        0.0   0.0       0.0
# d2  0.000000     0.000000  0.000000  ...        0.0   0.0       0.0
# d3  0.000000     0.000000  0.000000  ...        0.0   0.0       0.0
# d4  0.000000     0.000000  0.000000  ...        0.0   0.0       0.0
# d5  0.000000     0.000000  0.000000  ...        0.0   0.0       0.0
#
#     apolloway  unetix  calistogas  commencing  moffett  whereof  hereto
# ...

# %%
from pandas.core.internals.array_manager import T
def tfidfScore(query):
  binary_res = {}
  rowcount_res = {}
  termfreq_res = {}
  lognorm_res = {}
  dnorm_res = {}

  columns = list(binary_tfidf.columns)
  tokens = preprocessing(query)

  for index in binary_tfidf.index:
    sumb,sumr,sumt,suml,sumd = 0,0,0,0,0
    for term in tokens:
      if term in columns:
        sumb += binary_tfidf.loc[index,term]
        sumr += rowcount_tfidf.loc[index,term]
        sumt += termfrequency_tfidf.loc[index,term]
        suml += lognormalization_tfidf.loc[index,term]
        sumd += dnormalization_tfidf.loc[index,term]
    
    binary_res[index] = sumb
    rowcount_res[index] = sumr
    termfreq_res[index] = sumt
    lognorm_res[index] = suml
    dnorm_res[index] = sumd

  binary_res = sorted(binary_res.items(), key=lambda x: x[1], reverse=True)
  rowcount_res = sorted(rowcount_res.items(), key=lambda x: x[1], reverse=True)
  termfreq_res = sorted(termfreq_res.items(), key=lambda x: x[1], reverse=True)
  lognorm_res = sorted(lognorm_res.items(), key=lambda x: x[1], reverse=True)
  dnorm_res = sorted(dnorm_res.items(), key=lambda x: x[1], reverse=True)
  

  return binary_res,rowcount_res,termfreq_res,lognorm_res,dnorm_res

# %%
binary,row,term,lognorm,dnorm = tfidfScore("rinaldo agriculture")

# %%
print(binary)
print(row)
print(term)
print(lognorm)
print(dnorm)
# Out:
# [('d1', 2.452169918535435), ('d415', 2.452169918535435), ('d515', 2.452169918535435), ('d3', 2.2091318698491405), ('d257', 2.2091318698491405), ('d504', 2.2091318698491405), ('d915', 2.2091318698491405), ('d968', 2.2091318698491405), ('d1096', 2.2091318698491405), ('d2', 0.0), ('d4', 0.0), ('d5', 0.0), ('d6', 0.0), ('d7', 0.0), ('d8', 0.0), ('d9', 0.0), ('d10', 0.0), ('d11', 0.0), ('d12', 0.0), ('d13', 0.0), ('d14', 0.0), ('d15', 0.0), ('d16', 0.0), ('d17', 0.0), ('d18', 0.0), ('d19', 0.0), ('d20', 0.0), ('d21', 0.0), ('d22', 0.0), ('d23', 0.0), ('d24', 0.0), ('d25', 0.0), ('d26', 0.0), ('d27', 0.0), ('d28', 0.0), ('d29', 0.0), ('d30', 0.0), ('d31', 0.0), ('d32', 0.0), ('d33', 0.0), ('d34', 0.0), ('d35', 0.0), ('d36', 0.0), ('d37', 0.0), ('d38', 0.0), ('d39', 0.0), ('d40', 0.0), ('d41', 0.0), ('d42', 0.0), ('d43', 0.0), ('d44', 0.0), ('d45', 0.0), ('d46', 0.0), ('d47', 0.0), ('d48', 0.0), ('d49', 0.0), ('d50', 0.0), ('d51', 0.0), ('d52', 0.0), ('d53', 0.0), ('d54', 0.0), ('d55', 0.0)
# ...
